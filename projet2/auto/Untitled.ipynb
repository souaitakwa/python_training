# %%
import pandas as pd

# %%
data = pd.read_csv("cars_brand.csv")

# %%
data.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  year  origin  \
# 0          8         307.0       130.0  3504.0          12.0    70       1
# 1          8         350.0       165.0  3693.0          11.5    70       1
# 2          8         318.0       150.0  3436.0          11.0    70       1
# 3          8         304.0       150.0  3433.0          12.0    70       1
# 4          8         302.0       140.0  3449.0          10.5    70       1
#
#                         name  target      brand
# 0  chevrolet chevelle malibu    18.0  chevrolet
# 1          buick skylark 320    15.0      buick
# 2         plymouth satellite    18.0   plymouth
# 3              amc rebel sst    16.0        amc
# 4                ford torino    17.0       ford

# %%
cars = data[["name","brand"]]

# %%
cars.head()
# Out:
#                         name      brand
# 0  chevrolet chevelle malibu  chevrolet
# 1          buick skylark 320      buick
# 2         plymouth satellite   plymouth
# 3              amc rebel sst        amc
# 4                ford torino       ford

# %%
data.drop("brand", axis =1 , inplace=True )

# %%
data.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  year  origin  \
# 0          8         307.0       130.0  3504.0          12.0    70       1
# 1          8         350.0       165.0  3693.0          11.5    70       1
# 2          8         318.0       150.0  3436.0          11.0    70       1
# 3          8         304.0       150.0  3433.0          12.0    70       1
# 4          8         302.0       140.0  3449.0          10.5    70       1
#
#                         name  target
# 0  chevrolet chevelle malibu    18.0
# 1          buick skylark 320    15.0
# 2         plymouth satellite    18.0
# 3              amc rebel sst    16.0
# 4                ford torino    17.0

# %%
tab = pd.merge(left =data , right =cars , on="name" , how = "left")

# %%
tab.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  year  origin  \
# 0          8         307.0       130.0  3504.0          12.0    70       1
# 1          8         307.0       130.0  3504.0          12.0    70       1
# 2          8         350.0       165.0  3693.0          11.5    70       1
# 3          8         318.0       150.0  3436.0          11.0    70       1
# 4          8         304.0       150.0  3433.0          12.0    70       1
#
#                         name  target      brand
# 0  chevrolet chevelle malibu    18.0  chevrolet
# 1  chevrolet chevelle malibu    18.0  chevrolet
# 2          buick skylark 320    15.0      buick
# 3         plymouth satellite    18.0   plymouth
# 4              amc rebel sst    16.0        amc

# %% [markdown]
# ki ybda aandk 2 bases w columns maandhomch nafs l esm
# > on_left="name", on_right="el esm lekher"
